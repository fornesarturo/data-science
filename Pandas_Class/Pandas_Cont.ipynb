# %% [markdown]
# # Where to look for data

# %% [markdown]
# - https://www.reddit.com/r/bigquery/wiki/datasets
# - Kaggle
# - wikipedia datasets
# - datos.gob
# - data.gov
# - stanford NLP datasets and others
# - CMU datasets
# - MNIST
# - MNIST-Fashion
# - Image-Net
# - Twitter
# - Facebook
# - Facebook AI research (FAIR)
# - Instagram?

# %% [markdown]
# # Re-Indexing

# %%
import pandas as pd

# %%
df=pd.DataFrame({'A':[1,2,3],'B':[6,5,4]}) #, index=['Q',2,3])

# %%
df
# Out:
#    A  B
# 0  1  6
# 1  2  5
# 2  3  4

# %%
df = df.reindex([0,1,2,3,4])

# %%
df
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  5.0
# 2  3.0  4.0
# 3  NaN  NaN
# 4  NaN  NaN

# %%
df =df.reindex([0,1,2,3,4,5,6], fill_value=0)
print(df)
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  5.0
# 2  3.0  4.0
# 3  NaN  NaN
# 4  NaN  NaN
# 5  0.0  0.0
# 6  0.0  0.0

# %% [markdown]
# # Drop Entry

# %%
df=df.dropna()

# %%
df
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  5.0
# 2  3.0  4.0
# 5  0.0  0.0
# 6  0.0  0.0

# %%
df.drop(1)
# Out:
#      A    B
# 0  1.0  6.0
# 2  3.0  4.0
# 5  0.0  0.0
# 6  0.0  0.0

# %%
df
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  5.0
# 2  3.0  4.0
# 5  0.0  0.0
# 6  0.0  0.0

# %%
df.drop('A', axis=1)
# Out:
#      B
# 0  6.0
# 1  5.0
# 2  4.0
# 5  0.0
# 6  0.0

# %%
df
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  5.0
# 2  3.0  4.0
# 5  0.0  0.0
# 6  0.0  0.0

# %%
# Remember that for a change to be permanent you have to set df = df.drop(something)

df = df.drop('A',axis=1)
print(df)
# Out:
#      B
# 0  6.0
# 1  5.0
# 2  4.0
# 5  0.0
# 6  0.0

# %% [markdown]
# # Fill with the mean

# %%
df=pd.DataFrame({'A':[1,2,3],'B':[6,5,4]}) #, index=['Q',2,3])
df =df.reindex([0,1,2,3])
df
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  5.0
# 2  3.0  4.0
# 3  NaN  NaN

# %%
df.fillna(df.mean(), inplace=True)
df
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  5.0
# 2  3.0  4.0
# 3  2.0  5.0

# %% [markdown]
# # Selecting Entries

# %%
df['C']=[1,2,3,4]

# %%
df
# Out:
#      A    B  C
# 0  1.0  6.0  1
# 1  2.0  5.0  2
# 2  3.0  4.0  3
# 3  2.0  5.0  4

# %%
df['C'][3]
# Out:
# 4

# %%
df['B'][2]
# Out:
# 4.0

# %%
# df['B'][3]  # this should throw an error

# %%
list('ABCDEFG')
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df.loc[0]
# Out:
# A    1.0
# B    6.0
# C    1.0
# Name: 0, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  6.0  1
# 1  2.0  5.0  2
# 2  3.0  4.0  3
# 3  2.0  5.0  4

# %% [markdown]
# # Sorting DataFrames

# %%
df2=pd.DataFrame([[1,2],[3,4]], index=list('BA'))

# %%
df2
# Out:
#    0  1
# B  1  2
# A  3  4

# %%
df2.sort_index()
# Out:
#    0  1
# A  3  4
# B  1  2

# %% [markdown]
# # Basic operations

# %%
df
# Out:
#      A    B  C
# 0  1.0  6.0  1
# 1  2.0  5.0  2
# 2  3.0  4.0  3
# 3  2.0  5.0  4

# %%
df.sum()
# Out:
# A     8.0
# B    20.0
# C    10.0
# dtype: float64

# %%
df.cumsum()
# Out:
#      A     B     C
# 0  1.0   6.0   1.0
# 1  3.0  11.0   3.0
# 2  6.0  15.0   6.0
# 3  8.0  20.0  10.0

# %% [markdown]
# # Pivoting

# %%
import pandas as pd
df1 = pd.read_csv('unpivot.csv')

# %%
df1
# Out:
#           date variable     value
# 0   03/01/2000        A -0.046463
# 1   04/01/2000        A -0.173593
# 2   05/01/2000        A  1.131152
# 3   03/01/2000        B -0.114660
# 4   04/01/2000        B  0.141919
# 5   05/01/2000        B -0.939512
# 6   03/01/2000        C  2.165012
# 7   04/01/2000        C -0.850759
# 8   05/01/2000        C -0.799248
# 9   03/01/2000        D -1.522259
# 10  04/01/2000        D  1.116091
# 11  05/01/2000        D  0.297002

# %%
# df.pivot(ROWS,COLUMNS,VALUES)
df_pivot = df1.pivot('date','variable','value')

# %%
df_pivot
# Out:
# variable           A         B         C         D
# date
# 03/01/2000 -0.046463 -0.114660  2.165012 -1.522259
# 04/01/2000 -0.173593  0.141919 -0.850759  1.116091
# 05/01/2000  1.131152 -0.939512 -0.799248  0.297002

# %% [markdown]
# # Mapping

# %%
dframe = pd.DataFrame({'city':['Tepic','Guadalajara','Las demas', 'Tepic'],
                    'altitude':[1000,8000,10000,1000]})

# %%
dframe
# Out:
#           city  altitude
# 0        Tepic      1000
# 1  Guadalajara      8000
# 2    Las demas     10000
# 3        Tepic      1000

# %%
Estados={'Tepic':'Nayarit','Guadalajara':'Jalisco','Las demas':'Algun estado'}

# %%
dframe['State'] = dframe['city'].map(Estados)

# %%
dframe
# Out:
#           city  altitude         State
# 0        Tepic      1000       Nayarit
# 1  Guadalajara      8000       Jalisco
# 2    Las demas     10000  Algun estado
# 3        Tepic      1000       Nayarit

# %% [markdown]
# # Let's Analyze the cannabis Industry

# %%
import pandas_datareader as pdr
import datetime

# %% [markdown]
# Get data from yahoo stocks

# %%
stocks = pdr.get_data_yahoo(['WEED.TO','ACB.TO','BP','BTI'],start=datetime.datetime(2017,1,1), end= datetime.datetime(2019,1,30))

# 2019-01-23    8.26  40.119999  32.369999  58.150002
# 2019-01-24    8.84  40.110001  31.480000  59.020000
# 2019-01-25    8.88  40.110001  31.410000  64.099998
# 2019-01-28    9.41  39.570000  32.000000  67.220001
# 2019-01-29    9.09  40.200001  33.290001  62.540001
# 2019-01-30    9.08  40.669998  34.570000  63.090000
#
# [492 rows x 4 columns]

# %%
type(stocks)
# Out:
# pandas.core.frame.DataFrame

# %%
stocks.to_csv('stocks.csv')

# %%
import matplotlib.pyplot as plt
stocks['Close'].plot()

# %%
returns = stocks['Close'].pct_change()

# %%
returns.columns
# Out:
# Index(['ACB.TO', 'BP', 'BTI', 'WEED.TO'], dtype='object', name='Symbols')

# %%
returns[['ACB.TO', 'BP']].plot()

# %%
returns.cumsum().plot()

# %%
#returns

# %%
returns.cumsum().plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(returns.corr())

# %%
stocks['Close'].plot()

# %% [markdown]
# #### Compare the stock prices of WEED.T vs British Petroleum

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
#stocks = pdr.get_data_yahoo(['WEED.TO','ACB.TO','BP','BTI'],start=datetime.datetime(2017,1,1), end= datetime.datetime(2019,1,30))

# %%
stocks['Close'][['WEED.TO','BP']].plot(legend=True,figsize=(10,4))

# %% [markdown]
# Now, plot the volume of the stocks being traded

# %%
stocks['Volume'][['WEED.TO','BP']].plot(legend=True,figsize=(10,4))

# %% [markdown]
# ### Let's compute the moving average of the stocks for windows sizes of: 10, 20, 30 for the Close price of British petroleum

# %%
MA = [10,20,30]
for window in MA:
    column_name = 'MA' + str(window)
    stocks[column_name]=stocks['Close']['BP'].rolling(window).mean()

# %%
#stocks2.head(11)

# %%
stocks[['MA10','MA20','MA30']].plot(subplots=False,figsize=(10,4))

# %% [markdown]
# ### Great, now let's get an overall look at the average daily return using a histogram. We'll use seaborn to create both a histogram and kde plot on the same figure

# %%
returns.head()
# Out:
# Symbols       ACB.TO        BP       BTI   WEED.TO
# Date
# 2017-01-03       NaN       NaN       NaN       NaN
# 2017-01-04  0.012605  0.007632 -0.002213  0.082002
# 2017-01-05  0.024896  0.007313  0.001064 -0.027559
# 2017-01-06 -0.012146 -0.017112 -0.002747 -0.010121
# 2017-01-09  0.061475 -0.015827  0.010306  0.014315

# %%
# Note the use of dropna() here, otherwise the NaN values can't be read by seaborn
sns.distplot(returns['BP'].dropna(),bins=50,color='purple')

# Could have also done:
#AAPL['Daily Return'].hist()

# %% [markdown]
# Now that we have all the closing prices, let's go ahead and get the daily return for all the stocks, like we did for the Apple stock.

# %% [markdown]
# Constellation Brands, vegan, love, pepsico, camila cabello

# %%
sns.jointplot('ACB.TO', 'WEED.TO', returns, kind="scatter", color="seagreen")

# %%
sns.pairplot(returns.dropna())

# %%
returns_fig = sns.PairGrid(returns.dropna())

returns_fig.map_upper(plt.scatter, color="purple")

returns_fig.map_lower(sns.kdeplot, cmap="cool_d")

returns_fig.map_diag(plt.hist, bins=30)
